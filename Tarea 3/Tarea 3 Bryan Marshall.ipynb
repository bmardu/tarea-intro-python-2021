# %% [markdown]
# ### 1. Cargue los datos del archivo CSV 'hipparcos-voidmain.csv' en un nuevo DataFrame. Los archivos se encuentran en la carpeta principal de la Sesión 5.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\bryan\Documents\Programación\Python\Curso NineHub\intro-a-python-hc02\05 - Sesion 5\hipparcos-voidmain.csv')

# %% [markdown]
# ### 2. Muestre las últimas 5 filas del DataFrame.

# %%
df.tail()
# Out:
#        Catalog     HIP Proxy        RAhms        DEdms  Vmag  VarFlag r_Vmag  \
# 118213       H  118318   NaN  23 59 51.30  +11 40 25.4  6.99      1.0      H
# 118214       H  118319   NaN  23 59 53.74  -22 25 41.4  8.23      NaN      G
# 118215       H  118320   NaN  23 59 54.25  +05 57 23.9  7.59      NaN      H
# 118216       H  118321   NaN  23 59 54.78  -64 22 21.3  9.20      NaN      G
# 118217       H  118322   NaN  23 59 54.91  -65 34 37.5  4.49      NaN      H
#
#              RAdeg      DEdeg  ... Survey  Chart  Notes        HD         BD  \
# 118213  359.963744  11.673709  ...      S    NaN    NaN  224673.0  B+10 5018
# 118214  359.973913 -22.428180  ...      S    NaN    NaN  224693.0        NaN
# 118215  359.976057   5.956638  ...      S    NaN    NaN  224689.0  B+05 5245
# 118216  359.978239 -64.372572  ...    NaN    NaN    NaN  224685.0        NaN
# 118217  359.978792 -65.577078  ...      S    NaN    NaN  224686.0        NaN
#
#                CoD         CPD  (V-I)red  SpType  r_SpType
# 118213         NaN         NaN      1.56      K2         S
# 118214  C-23 18108  P-23  8366      0.70     G2V         4
# 118215         NaN         NaN      0.98      K0         S
# 118216  C-65  2958  P-65  4188      0.75     G5V         1
# 118217         NaN  P-66  3819     -0.04    B9IV         X
#
# [5 rows x 78 columns]

# %% [markdown]
# ### 3. Muestre las primeras 3 columnas del DataFrame.

# %%
pd.set_option("display.max.columns", None)
df1 = df.loc[:,['Catalog','HIP']]
df1
# Out:
#        Catalog     HIP
# 0            H       1
# 1            H       2
# 2            H       3
# 3            H       4
# 4            H       5
# ...        ...     ...
# 118213       H  118318
# 118214       H  118319
# 118215       H  118320
# 118216       H  118321
# 118217       H  118322
#
# [118218 rows x 2 columns]

# %% [markdown]
# ### 4. A partir del DataFrame original, cree un nuevo DataFrame que contenga las columnas 'HIP', 'RAhms', 'DEdms', 'Vmag', 'Plx', 'SpType', 'B-V'.

# %%
df2 = df.loc[:,['HIP', 'RAhms', 'DEdms', 'Vmag', 'Plx', 'SpType', 'B-V']]
df2
# Out:
#            HIP        RAhms        DEdms  Vmag    Plx SpType    B-V
# 0            1  00 00 00.22  +01 05 20.4  9.10   3.54     F5  0.482
# 1            2  00 00 00.91  -19 29 55.8  9.27  21.90    K3V  0.999
# 2            3  00 00 01.20  +38 51 33.4  6.61   2.81     B9 -0.019
# 3            4  00 00 02.01  -51 53 36.8  8.06   7.75    F0V  0.370
# 4            5  00 00 02.39  -40 35 28.4  8.55   2.87  G8III  0.902
# ...        ...          ...          ...   ...    ...    ...    ...
# 118213  118318  23 59 51.30  +11 40 25.4  6.99   1.92     K2  1.595
# 118214  118319  23 59 53.74  -22 25 41.4  8.23  10.63    G2V  0.639
# 118215  118320  23 59 54.25  +05 57 23.9  7.59   5.00     K0  0.999
# 118216  118321  23 59 54.78  -64 22 21.3  9.20  19.22    G5V  0.698
# 118217  118322  23 59 54.91  -65 34 37.5  4.49   8.71   B9IV -0.075
#
# [118218 rows x 7 columns]

# %% [markdown]
# ### 5. Cambie el nombre de la columna 'B-V' a 'BV'.

# %%
df2.rename(columns={'B-V': 'BV'},inplace=True)
df2
# Out:
#            HIP        RAhms        DEdms  Vmag    Plx SpType     BV
# 0            1  00 00 00.22  +01 05 20.4  9.10   3.54     F5  0.482
# 1            2  00 00 00.91  -19 29 55.8  9.27  21.90    K3V  0.999
# 2            3  00 00 01.20  +38 51 33.4  6.61   2.81     B9 -0.019
# 3            4  00 00 02.01  -51 53 36.8  8.06   7.75    F0V  0.370
# 4            5  00 00 02.39  -40 35 28.4  8.55   2.87  G8III  0.902
# ...        ...          ...          ...   ...    ...    ...    ...
# 118213  118318  23 59 51.30  +11 40 25.4  6.99   1.92     K2  1.595
# 118214  118319  23 59 53.74  -22 25 41.4  8.23  10.63    G2V  0.639
# 118215  118320  23 59 54.25  +05 57 23.9  7.59   5.00     K0  0.999
# 118216  118321  23 59 54.78  -64 22 21.3  9.20  19.22    G5V  0.698
# 118217  118322  23 59 54.91  -65 34 37.5  4.49   8.71   B9IV -0.075
#
# [118218 rows x 7 columns]

# %% [markdown]
# ### 6. ¿Cuál es el valor máximo de las magnitudes aparentes en la columna 'Vmag'? ¿Cuál es el valor mínimo?

# %%
vmag = df2.Vmag
vmag
# Out:
# 0         9.10
# 1         9.27
# 2         6.61
# 3         8.06
# 4         8.55
#           ...
# 118213    6.99
# 118214    8.23
# 118215    7.59
# 118216    9.20
# 118217    4.49
# Name: Vmag, Length: 118218, dtype: float64

# %%
mayor = vmag.max()
menor = vmag.min()
print("El valor máximo es " + str(mayor) + " y el mínimo es " + str(menor))
# Out:
# El valor máximo es 14.08 y el mínimo es -1.44

# %% [markdown]
# ### 7. Muestre la columna 'Vmag'en orden ascendente. Ayuda: puede utilizar '.sort_values()' y elegir la columna correcta.

# %%
df2.sort_values('Vmag', ascending=True)
# Out:
#            HIP        RAhms        DEdms   Vmag     Plx  SpType     BV
# 32324    32349  06 45 09.25  -16 42 47.3  -1.44  379.21  A0m...  0.009
# 30416    30438  06 23 57.09  -52 41 44.6  -0.62   10.43    F0Ib  0.164
# 69609    69673  14 15 40.35  +19 11 14.2  -0.05   88.85  K2IIIp  1.239
# 71618    71683  14 39 40.90  -60 50 06.5  -0.01  742.12     G2V  0.710
# 91179    91262  18 36 56.19  +38 46 58.8   0.03  128.93  A0Vvar -0.001
# ...        ...          ...          ...    ...     ...     ...    ...
# 15547    15562  03 20 28.92  +22 24 56.8  13.63  -29.58     NaN  0.800
# 36618    36649  07 32 14.27  +14 05 15.2  13.64     NaN     NaN    NaN
# 105199  105296  21 19 38.13  -32 26 21.9  13.78     NaN     G0V    NaN
# 70015    70079  14 20 28.21  -44 31 56.3  14.08  -20.09     NaN    NaN
# 25189   120412  05 23 33.71  -60 55 29.0    NaN     NaN     NaN    NaN
#
# [118218 rows x 7 columns]

# %% [markdown]
# ### 8. ¿Cuántas estrellas tienen una magnitud aparente superior a 10.0? Seleccione solo estas estrellas en el DataFrame y muéstrelas. Guarde estos datos en un nuevo .csv llamado 'estrellas_filtro.csv'.

# %%
df2[df2.Vmag>10.0]
# Out:
#            HIP        RAhms        DEdms   Vmag    Plx SpType     BV
# 5            6  00 00 04.35  +03 56 47.4  12.31  18.80   M0V:  1.336
# 16          16  00 00 12.34  -54 54 50.9  11.71   0.53    NaN  0.421
# 17          18  00 00 12.75  -04 03 13.5  11.03  19.93     K5  1.567
# 36          37  00 00 25.28  -47 10 46.5  10.44   3.74    F0V  0.391
# 40          40  00 00 29.27  +67 13 00.4  10.61  -3.40   B...  0.570
# ...        ...          ...          ...    ...    ...    ...    ...
# 118135  118240  23 58 58.48  +64 53 18.0  11.41   7.24    NaN  0.770
# 118169  118274  23 59 26.72  -28 51 13.8  10.11   3.09    NaN  0.439
# 118200  118305  23 59 44.74  +08 41 21.0  11.94  10.07     K7  1.281
# 118207  118311  23 59 49.12  -38 15 09.4  11.85  24.63    NaN  1.391
# 118212  118317  23 59 50.81  -36 25 10.1  10.01   3.42     F8  0.549
#
# [10214 rows x 7 columns]

# %%
df2.to_csv('estrellas_filtro.csv')

# %% [markdown]
# ### 9. ¿Cuántas estrellas tienen un índice B-V entre 0.3 y 0.6? Muestre estas estrellas y cuente su total. Grafique esta porción de las estrellas en un histograma. Ajuste los rangos y bins como sea necesario.

# %%
df2[(0.6>df2.BV) & (df2.BV>0.3)]
# Out:
#            HIP        RAhms        DEdms   Vmag    Plx SpType     BV
# 0            1  00 00 00.22  +01 05 20.4   9.10   3.54     F5  0.482
# 3            4  00 00 02.01  -51 53 36.8   8.06   7.75    F0V  0.370
# 9           10  00 00 08.70  -50 52 01.5   8.59  10.76    F6V  0.489
# 15          17  00 00 12.26  -40 11 32.4   8.15   6.15    F3V  0.425
# 16          16  00 00 12.34  -54 54 50.9  11.71   0.53    NaN  0.421
# ...        ...          ...          ...    ...    ...    ...    ...
# 118189  118294  23 59 35.10  -07 48 37.8   8.69   8.09     G0  0.551
# 118196  118301  23 59 43.22  +21 17 21.1   7.67   5.54    F2V  0.337
# 118208  118313  23 59 49.40  +21 08 59.1   8.94   2.32     F0  0.423
# 118211  118316  23 59 50.62  +32 32 13.0   9.51   3.10     F2  0.468
# 118212  118317  23 59 50.81  -36 25 10.1  10.01   3.42     F8  0.549
#
# [31011 rows x 7 columns]

# %%
df2[(0.6>df2.BV) & (df2.BV>0.3)].count()
# Out:
# HIP       31011
# RAhms     31011
# DEdms     31011
# Vmag      31011
# Plx       30989
# SpType    30634
# BV        31011
# dtype: int64

# %%
plt.hist(df2['BV'], range=[0.3, 0.6], bins=10)
# Out:
# (array([1993., 2171., 2462., 3228., 3337., 3753., 4005., 3684., 3620.,
#         3176.]),
#  array([0.3 , 0.33, 0.36, 0.39, 0.42, 0.45, 0.48, 0.51, 0.54, 0.57, 0.6 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 10. Replique el diagrama H-R realizado en la lección 6. Necesitará calcular la Magnitud Absoluta como se hizo en la Sesión 6.

# %%
df2.insert(loc=1,column='Distancia',value='')
df2.insert(loc=5,column='AbsMag',value='')

# %%
df2['Distancia'] = (1/(df2['Plx']*10**-3))
df2['AbsMag'] = df2['Vmag'] - 5*np.log10(df2['Distancia']) + 5
df2
# Out:
#            HIP   Distancia        RAhms        DEdms  Vmag    AbsMag    Plx  \
# 0            1  282.485876  00 00 00.22  +01 05 20.4  9.10  1.845016   3.54
# 1            2   45.662100  00 00 00.91  -19 29 55.8  9.27  5.972221  21.90
# 2            3  355.871886  00 00 01.20  +38 51 33.4  6.61 -1.146468   2.81
# 3            4  129.032258  00 00 02.01  -51 53 36.8  8.06  2.506509   7.75
# 4            5  348.432056  00 00 02.39  -40 35 28.4  8.55  0.839409   2.87
# ...        ...         ...          ...          ...   ...       ...    ...
# 118213  118318  520.833333  23 59 51.30  +11 40 25.4  6.99 -1.593494   1.92
# 118214  118319   94.073377  23 59 53.74  -22 25 41.4  8.23  3.362666  10.63
# 118215  118320  200.000000  23 59 54.25  +05 57 23.9  7.59  1.084850   5.00
# 118216  118321   52.029136  23 59 54.78  -64 22 21.3  9.20  5.618767  19.22
# 118217  118322  114.810563  23 59 54.91  -65 34 37.5  4.49 -0.809909   8.71
#
#        SpType     BV
# 0          F5  0.482
# 1         K3V  0.999
# 2          B9 -0.019
# 3         F0V  0.370
# 4       G8III  0.902
# ...       ...    ...
# 118213     K2  1.595
# 118214    G2V  0.639
# 118215     K0  0.999
# 118216    G5V  0.698
# 118217   B9IV -0.075
#
# [118218 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(10,12))

ax.set_xlim(-0.5, 2.5)
ax.set_ylim(15, -10)
ax.grid()
ax.set_title('H-R Diagram - Hipparcos Catalog')

ax.title.set_fontsize(20)
ax.set_xlabel('Índice de color B-V')
ax.set_ylabel('Magnitud absoluta')
plt.scatter(df2['BV'], df2['AbsMag'], s=1)

# %% [markdown]
# ### 11. Guarde el diagrama H-R como una imagen en formato PNG utilizando la función de matplotlib 'plt.savefig('hr.png')'

# %%
plt.savefig('hr.png')
